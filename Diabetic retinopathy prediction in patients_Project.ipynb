# %%
# Import necessary libraries
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
from io import StringIO


# Load the dataset
data = pd.read_csv(r'D:\HI448116_Santosh_Karpe\FY25\DOCS\III\Ass\P2\pronostico_dataset.csv',delimiter=';')


# Display the first few rows of the dataset
data.head()
# Out:
#    ID        age  systolic_bp  diastolic_bp  cholesterol    prognosis
# 0   0  77.196340    85.288742     80.021878    79.957109  retinopathy
# 1   1  63.529850    99.379736     84.852361   110.382411  retinopathy
# 2   2  69.003986   111.349455    109.850616   100.828246  retinopathy
# 3   3  82.638210    95.056128     79.666851    87.066303  retinopathy
# 4   4  78.346286   109.154591     90.713220    92.511770  retinopathy

# %%
#Understand the Dataset

# %%
# Check basic information about the dataset
data.info()

# Get statistical summary of the numerical columns
data.describe()

# Check for missing values
data.isnull().sum()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 6000 entries, 0 to 5999
# Data columns (total 6 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   ID            6000 non-null   int64
#  1   age           6000 non-null   float64
#  2   systolic_bp   6000 non-null   float64
#  3   diastolic_bp  6000 non-null   float64
#  4   cholesterol   6000 non-null   float64
#  5   prognosis     6000 non-null   object
# dtypes: float64(4), int64(1), object(1)
# memory usage: 281.4+ KB
# ID              0
# age             0
# systolic_bp     0
# diastolic_bp    0
# cholesterol     0
# prognosis       0
# dtype: int64

# %%
print(data.columns.to_list())
# Out:
# ['ID', 'age', 'systolic_bp', 'diastolic_bp', 'cholesterol', 'prognosis']

# %%
data.columns = data.columns.str.strip()

# %%
# Plot distribution for numerical columns
plt.figure(figsize=(12, 10))

# Age distribution
plt.subplot(2, 3, 1)
sns.histplot(data['age'], kde=True, color='blue')
plt.title('Age Distribution')

# Systolic BP distribution
plt.subplot(2, 3, 2)
sns.histplot(data['systolic_bp'], kde=True, color='green')
plt.title('Systolic BP Distribution')

# Diastolic BP distribution
plt.subplot(2, 3, 3)
sns.histplot(data['diastolic_bp'], kde=True, color='red')
plt.title('Diastolic BP Distribution')

# Cholesterol distribution
plt.subplot(2, 3, 4)
sns.histplot(data['cholesterol'], kde=True, color='purple')
plt.title('Cholesterol Distribution')

# Prognosis (target variable) distribution
plt.subplot(2, 3, 5)
sns.countplot(x='prognosis', data=data, palette='Set1')
plt.title('Prognosis Distribution')

plt.tight_layout()
plt.show()
# Out:
# C:\Users\hi448116\AppData\Local\Temp\ipykernel_32736\3848004535.py:26: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.countplot(x='prognosis', data=data, palette='Set1')

# %%
#Bivariate Analysis

# %%
# Age vs Prognosis
plt.figure(figsize=(10, 6))
sns.boxplot(x='prognosis', y='age', data=data, palette='Set1')
plt.title('Age vs Prognosis')
plt.show()

# Systolic BP vs Prognosis
plt.figure(figsize=(10, 6))
sns.boxplot(x='prognosis', y='systolic_bp', data=data, palette='Set1')
plt.title('Systolic BP vs Prognosis')
plt.show()

# Diastolic BP vs Prognosis
plt.figure(figsize=(10, 6))
sns.boxplot(x='prognosis', y='diastolic_bp', data=data, palette='Set1')
plt.title('Diastolic BP vs Prognosis')
plt.show()

# Cholesterol vs Prognosis
plt.figure(figsize=(10, 6))
sns.boxplot(x='prognosis', y='cholesterol', data=data, palette='Set1')
plt.title('Cholesterol vs Prognosis')
plt.show()
# Out:
# C:\Users\hi448116\AppData\Local\Temp\ipykernel_32736\973805590.py:3: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.boxplot(x='prognosis', y='age', data=data, palette='Set1')
# C:\Users\hi448116\AppData\Local\Temp\ipykernel_32736\973805590.py:9: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.boxplot(x='prognosis', y='systolic_bp', data=data, palette='Set1')
# C:\Users\hi448116\AppData\Local\Temp\ipykernel_32736\973805590.py:15: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.boxplot(x='prognosis', y='diastolic_bp', data=data, palette='Set1')
# ...

# %%
# Correlation Analysis

# %%
# Correlation matrix
corr = data[['age', 'systolic_bp', 'diastolic_bp', 'cholesterol']].corr()

# Plot the correlation matrix
plt.figure(figsize=(8, 6))
sns.heatmap(corr, annot=True, cmap='coolwarm', vmin=-1, vmax=1)
plt.title('Correlation Matrix')
plt.show()

# %%
#Visualizations

# %%
sns.pairplot(data[['age', 'systolic_bp', 'diastolic_bp', 'cholesterol', 'prognosis']], hue='prognosis')
plt.show()

# %%
# Heatmap for Outliers:

# %%
# Visualize distribution using boxplots
plt.figure(figsize=(12, 10))

# Age boxplot
plt.subplot(2, 3, 1)
sns.boxplot(x=data['age'])
plt.title('Age Boxplot')

# Systolic BP boxplot
plt.subplot(2, 3, 2)
sns.boxplot(x=data['systolic_bp'])
plt.title('Systolic BP Boxplot')

# Diastolic BP boxplot
plt.subplot(2, 3, 3)
sns.boxplot(x=data['diastolic_bp'])
plt.title('Diastolic BP Boxplot')

# Cholesterol boxplot
plt.subplot(2, 3, 4)
sns.boxplot(x=data['cholesterol'])
plt.title('Cholesterol Boxplot')

plt.tight_layout()
plt.show()

# %%
#Outlier Detection

# %%
# Z-Score Outlier Detection (for example, for 'age' column)
from scipy.stats import zscore

z_scores = np.abs(zscore(data[['age', 'systolic_bp', 'diastolic_bp', 'cholesterol']]))
outliers = (z_scores > 3).all(axis=1)

# Display rows with outliers
data[outliers]
# Out:
# Empty DataFrame
# Columns: [ID, age, systolic_bp, diastolic_bp, cholesterol, prognosis]
# Index: []

# %%
#Model Building

# %%
# Display the first few rows of the dataset
data.head()
# Out:
#          age  systolic_bp  diastolic_bp  cholesterol    prognosis
# 0  77.196340    85.288742     80.021878    79.957109  retinopathy
# 1  63.529850    99.379736     84.852361   110.382411  retinopathy
# 2  69.003986   111.349455    109.850616   100.828246  retinopathy
# 3  82.638210    95.056128     79.666851    87.066303  retinopathy
# 4  78.346286   109.154591     90.713220    92.511770  retinopathy

# %%
#Model Selection

# %%
import pandas as pd
from sklearn.model_selection import train_test_split
from sklearn.svm import SVC
from sklearn.preprocessing import StandardScaler
from sklearn.metrics import classification_report

# Load the data from CSV file
data = pd.read_csv(r'D:\HI448116_Santosh_Karpe\FY25\DOCS\III\Ass\P2\pronostico_dataset.csv',delimiter=';')

# Check for missing values
print(data.isnull().sum())

# Split the data into features (X) and target (y)
X = data[['age', 'systolic_bp', 'diastolic_bp', 'cholesterol']]  # Features
y = data['prognosis']  # Target variable

# Standardize the features (important for SVM)
scaler = StandardScaler()
X_scaled = scaler.fit_transform(X)

# Split the data into training and testing sets
X_train, X_test, y_train, y_test = train_test_split(X_scaled, y, test_size=0.2, random_state=42)

# Build an SVM model
model = SVC(kernel='linear', random_state=42)  # Linear kernel is often a good choice, but you can experiment with others
model.fit(X_train, y_train)

# Make predictions
y_pred = model.predict(X_test)

# Evaluate the model
print("Classification Report:")
print(classification_report(y_test, y_pred))

# Optionally, you can also check the accuracy of the model
accuracy = model.score(X_test, y_test)
print(f"Accuracy: {accuracy:.2f}")
# Out:
# ID              0
# age             0
# systolic_bp     0
# diastolic_bp    0
# cholesterol     0
# prognosis       0
# dtype: int64
# Classification Report:
#                 precision    recall  f1-score   support
#
# no_retinopathy       0.74      0.74      0.74       575
#    retinopathy       0.76      0.75      0.76       625
#
#       accuracy                           0.75      1200
#      macro avg       0.75      0.75      0.75      1200
#   weighted avg       0.75      0.75      0.75      1200
#
# Accuracy: 0.75

# %%
import numpy as np
import pandas as pd
from sklearn.model_selection import train_test_split
from sklearn.svm import SVC  # Support Vector Classification for classification
from sklearn.metrics import classification_report, accuracy_score
from sklearn.preprocessing import StandardScaler

# Load the CSV dataset
df = pd.read_csv(r'D:\HI448116_Santosh_Karpe\FY25\DOCS\III\Ass\P2\pronostico_dataset.csv', delimiter=';')

# Check the first few rows of the dataset to understand its structure
print(df.head())

# Assuming 'prognosis' is the target variable for classification
X = df[['age', 'systolic_bp', 'diastolic_bp', 'cholesterol']]  # Features
y = df['prognosis']  # Target variable (categorical)

# Split the dataset into training and testing sets
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.3, random_state=42)

# Standardize the features (important for SVM)
scaler = StandardScaler()
X_train_scaled = scaler.fit_transform(X_train)
X_test_scaled = scaler.transform(X_test)

# Initialize the SVC (Support Vector Classification) classifier
svm_classifier = SVC(kernel='linear')  # Using a linear kernel

# Train the model
svm_classifier.fit(X_train_scaled, y_train)

# Predict on the test set
y_pred = svm_classifier.predict(X_test_scaled)

# Evaluate the model
print(f"Accuracy: {accuracy_score(y_test, y_pred)}")
print("Classification Report:")
print(classification_report(y_test, y_pred))
# Out:
#    ID        age  systolic_bp  diastolic_bp  cholesterol    prognosis
# 0   0  77.196340    85.288742     80.021878    79.957109  retinopathy
# 1   1  63.529850    99.379736     84.852361   110.382411  retinopathy
# 2   2  69.003986   111.349455    109.850616   100.828246  retinopathy
# 3   3  82.638210    95.056128     79.666851    87.066303  retinopathy
# 4   4  78.346286   109.154591     90.713220    92.511770  retinopathy
# Accuracy: 0.7444444444444445
# Classification Report:
#                 precision    recall  f1-score   support
#
# no_retinopathy       0.74      0.74      0.74       873
#    retinopathy       0.75      0.75      0.75       927
#
#       accuracy                           0.74      1800
#      macro avg       0.74      0.74      0.74      1800
#   weighted avg       0.74      0.74      0.74      1800

# %%
import numpy as np
import pandas as pd
from sklearn.model_selection import train_test_split
from sklearn.neighbors import KNeighborsClassifier  # KNN for classification
from sklearn.metrics import classification_report, accuracy_score
from sklearn.preprocessing import StandardScaler

# Load the CSV dataset
df = pd.read_csv(r'D:\HI448116_Santosh_Karpe\FY25\DOCS\III\Ass\P2\pronostico_dataset.csv', delimiter=';')
# Check the first few rows of the dataset to understand its structure
print(df.head())

# Assuming 'prognosis' is the target variable for classification
X = df[['age', 'systolic_bp', 'diastolic_bp', 'cholesterol']]  # Features
y = df['prognosis']  # Target variable (categorical)

# Split the dataset into training and testing sets
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.3, random_state=42)

# Standardize the features (important for KNN)
scaler = StandardScaler()
X_train_scaled = scaler.fit_transform(X_train)
X_test_scaled = scaler.transform(X_test)

# Initialize the KNN classifier
knn_classifier = KNeighborsClassifier(n_neighbors=5)  # You can experiment with different values for n_neighbors

# Train the model
knn_classifier.fit(X_train_scaled, y_train)

# Predict on the test set
y_pred = knn_classifier.predict(X_test_scaled)

# Evaluate the model
print(f"Accuracy: {accuracy_score(y_test, y_pred)}")
print("Classification Report:")
print(classification_report(y_test, y_pred))
# Out:
#    ID        age  systolic_bp  diastolic_bp  cholesterol    prognosis
# 0   0  77.196340    85.288742     80.021878    79.957109  retinopathy
# 1   1  63.529850    99.379736     84.852361   110.382411  retinopathy
# 2   2  69.003986   111.349455    109.850616   100.828246  retinopathy
# 3   3  82.638210    95.056128     79.666851    87.066303  retinopathy
# 4   4  78.346286   109.154591     90.713220    92.511770  retinopathy
# Accuracy: 0.7305555555555555
# Classification Report:
#                 precision    recall  f1-score   support
#
# no_retinopathy       0.73      0.70      0.72       873
#    retinopathy       0.73      0.76      0.74       927
#
#       accuracy                           0.73      1800
#      macro avg       0.73      0.73      0.73      1800
#   weighted avg       0.73      0.73      0.73      1800

# %%
import numpy as np
import pandas as pd
from sklearn.model_selection import train_test_split
from sklearn.neighbors import KNeighborsRegressor  # KNN for regression
from sklearn.metrics import mean_squared_error, r2_score
from sklearn.preprocessing import StandardScaler

# Load the CSV dataset
df = pd.read_csv(r'D:\HI448116_Santosh_Karpe\FY25\DOCS\III\Ass\P2\pronostico_dataset.csv', delimiter=';')

# Check the first few rows of the dataset to understand its structure
print(df.head())

# Assuming 'prognosis' is the target variable for regression (continuous values)
X = df[['age', 'systolic_bp', 'diastolic_bp', 'cholesterol']]  # Features
y = df['age']  # Target variable (continuous)

# Split the dataset into training and testing sets
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.3, random_state=42)

# Standardize the features (important for KNN)
scaler = StandardScaler()
X_train_scaled = scaler.fit_transform(X_train)
X_test_scaled = scaler.transform(X_test)

# Initialize the KNN regressor
knn_regressor = KNeighborsRegressor(n_neighbors=5)  # You can experiment with different values for n_neighbors

# Train the model
knn_regressor.fit(X_train_scaled, y_train)

# Predict on the test set
y_pred = knn_regressor.predict(X_test_scaled)

# Evaluate the model
mse = mean_squared_error(y_test, y_pred)  # Mean Squared Error for regression
r2 = r2_score(y_test, y_pred)  # R-squared for regression

print(f"Mean Squared Error: {mse}")
print(f"R-squared: {r2}")
# Out:
#    ID        age  systolic_bp  diastolic_bp  cholesterol    prognosis
# 0   0  77.196340    85.288742     80.021878    79.957109  retinopathy
# 1   1  63.529850    99.379736     84.852361   110.382411  retinopathy
# 2   2  69.003986   111.349455    109.850616   100.828246  retinopathy
# 3   3  82.638210    95.056128     79.666851    87.066303  retinopathy
# 4   4  78.346286   109.154591     90.713220    92.511770  retinopathy
# Mean Squared Error: 1.284717796660617
# R-squared: 0.9826966379692378

# %%
import numpy as np
import pandas as pd
from sklearn.model_selection import train_test_split
from sklearn.neighbors import KNeighborsClassifier  # KNN for classification
from sklearn.metrics import accuracy_score, precision_score, recall_score, f1_score
from sklearn.preprocessing import StandardScaler

# Load the CSV dataset (ensure the delimiter is ';')
df = pd.read_csv(r'D:\HI448116_Santosh_Karpe\FY25\DOCS\III\Ass\P2\pronostico_dataset.csv', delimiter=';')

# Check the first few rows of the dataset
print(df.head())

# Drop the 'ID' column, which is not needed for prediction
X = df[['age', 'systolic_bp', 'diastolic_bp', 'cholesterol']]  # Features
y = df['prognosis']  # Target variable (categorical)

# Split the dataset into training and testing sets (70% training, 30% testing)
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.3, random_state=42)

# Standardize the features (important for KNN)
scaler = StandardScaler()
X_train_scaled = scaler.fit_transform(X_train)
X_test_scaled = scaler.transform(X_test)

# Initialize the KNN classifier with default parameters
knn = KNeighborsClassifier()

# Fit the KNN model on the training data
knn.fit(X_train_scaled, y_train)

# Predict on the testing set
y_pred = knn.predict(X_test_scaled)

# Evaluate the model's performance using various metrics
accuracy = accuracy_score(y_test, y_pred)
precision = precision_score(y_test, y_pred, average='weighted')
recall = recall_score(y_test, y_pred, average='weighted')
f1 = f1_score(y_test, y_pred, average='weighted')

# Print the evaluation metrics
print(f"Accuracy: {accuracy:.2f}")
print(f"Precision: {precision:.2f}")
print(f"Recall: {recall:.2f}")
print(f"F1-Score: {f1:.2f}")
# Out:
#    ID        age  systolic_bp  diastolic_bp  cholesterol    prognosis
# 0   0  77.196340    85.288742     80.021878    79.957109  retinopathy
# 1   1  63.529850    99.379736     84.852361   110.382411  retinopathy
# 2   2  69.003986   111.349455    109.850616   100.828246  retinopathy
# 3   3  82.638210    95.056128     79.666851    87.066303  retinopathy
# 4   4  78.346286   109.154591     90.713220    92.511770  retinopathy
# Accuracy: 0.73
# Precision: 0.73
# Recall: 0.73
# F1-Score: 0.73

# %%
import numpy as np
import pandas as pd
from sklearn.model_selection import train_test_split
from sklearn.svm import SVC  # Support Vector Classification for classification
from sklearn.metrics import classification_report, accuracy_score
from sklearn.preprocessing import StandardScaler
import pickle  # For saving the model and scaler

# Load the CSV dataset
df = pd.read_csv(r'D:\HI448116_Santosh_Karpe\FY25\DOCS\III\Ass\P2\pronostico_dataset.csv', delimiter=';')

# Check the first few rows of the dataset to understand its structure
print(df.head())

# Assuming 'prognosis' is the target variable for classification
X = df[['age', 'systolic_bp', 'diastolic_bp', 'cholesterol']]  # Features
y = df['prognosis']  # Target variable (categorical)

# Split the dataset into training and testing sets (70% training, 30% testing)
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.3, random_state=42)

# Standardize the features (important for SVM)
scaler = StandardScaler()
X_train_scaled = scaler.fit_transform(X_train)
X_test_scaled = scaler.transform(X_test)

# Initialize the SVC (Support Vector Classification) classifier
svm_classifier = SVC(kernel='linear')  # Using a linear kernel

# Train the model
svm_classifier.fit(X_train_scaled, y_train)

# Predict on the test set
y_pred = svm_classifier.predict(X_test_scaled)

# Evaluate the model's performance
accuracy = accuracy_score(y_test, y_pred)
print(f"Accuracy: {accuracy:.2f}")

# Display the classification report, including precision, recall, and F1-score for each class
print("Classification Report:")
print(classification_report(y_test, y_pred))

# Save the trained model and scaler as pickle files
with open('svm_classifier.pkl', 'wb') as f:
    pickle.dump(svm_classifier, f)

with open('scaler.pkl', 'wb') as f:
    pickle.dump(scaler, f)

print("Model and Scaler saved successfully!")
# Out:
#    ID        age  systolic_bp  diastolic_bp  cholesterol    prognosis
# 0   0  77.196340    85.288742     80.021878    79.957109  retinopathy
# 1   1  63.529850    99.379736     84.852361   110.382411  retinopathy
# 2   2  69.003986   111.349455    109.850616   100.828246  retinopathy
# 3   3  82.638210    95.056128     79.666851    87.066303  retinopathy
# 4   4  78.346286   109.154591     90.713220    92.511770  retinopathy
# Accuracy: 0.74
# Classification Report:
#                 precision    recall  f1-score   support
#
# no_retinopathy       0.74      0.74      0.74       873
#    retinopathy       0.75      0.75      0.75       927
#
#       accuracy                           0.74      1800
#      macro avg       0.74      0.74      0.74      1800
#   weighted avg       0.74      0.74      0.74      1800
#
# Model and Scaler saved successfully!
